# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
image_pre = "/inference_files/dataset/final_mdl_all_disaster_splits/raw/test/images/mexico-earthquake_00000135_pre_disaster_18.png"
image_post = "/inference_files/dataset/final_mdl_all_disaster_splits/raw/test/images/mexico-earthquake_00000135_post_disaster_18.png"
pred = "/inference_files/dataset/final_mdl_all_disaster_splits/raw/test/predictions/mexico-earthquake_00000135_18.png"
target_pre = "/inference_files/dataset/final_mdl_all_disaster_splits/raw/test/targets_border2/mexico-earthquake_00000135_pre_disaster_b2_18.png"
target_post = "/inference_files/dataset/final_mdl_all_disaster_splits/raw/test/targets_border2/mexico-earthquake_00000135_post_disaster_b2_18.png"

# %%
p = Image.open(pred)
im_pre = Image.open(image_pre)
im_post = Image.open(image_post)
t_pre = Image.open(target_pre)
t_post = Image.open(target_post)

# %%
plt.imshow(im_pre)

# %%
plt.imshow(im_post)

# %%
plt.imshow(t_pre)

# %%
plt.imshow(t_post)

# %%
# plt.imshow(np.array(t_pre) - np.array(t_post))
# Out:
# 0

# %%
plt.imshow(p)

# %%
# plt.imshow(p)
# print(p.data.max(), p.data.min())
import numpy as np
print(np.array(im_post).max(), np.array(im_post).min())
# Out:
# 255 32
